# %% [markdown]
# # 100 Matplotlib Coding Challenges by GiGi Molki.

# %% [markdown]
# ### 1. Plot a simple line graph of x = [1, 2, 3], y = [2, 4, 6].

# %% [markdown]
# ### 2. Change line style and color in a line plot.

# %% [markdown]
# ### 3. Add title, x-label, and y-label to a plot.

# %% [markdown]
# ### 4. Add a grid to the plot.

# %% [markdown]
# ### 5. Plot multiple lines in a single figure.

# %% [markdown]
# ### 6. Change line width and marker style.

# %% [markdown]
# ### 7. Save a plot to PNG and PDF.

# %% [markdown]
# ### 8. Display legends in a line plot.

# %% [markdown]
# ### 9. Customize legend position.

# %% [markdown]
# ### 10. Use LaTeX formatting in axis labels and titles.

# %% [markdown]
# ### 11. Plot a sine and cosine curve on the same figure.

# %% [markdown]
# ### 12. Set axis limits using plt.xlim() and plt.ylim().

# %% [markdown]
# ### 13. Display ticks at specific intervals.

# %% [markdown]
# ### 14. Rotate x-axis tick labels.

# %% [markdown]
# ### 15. Change background color of the plot.

# %% [markdown]
# ### 16. Create a bar plot for categorical data.

# %% [markdown]
# ### 17. Add data labels to a bar plot.

# %% [markdown]
# ### 18. Plot a horizontal bar chart.

# %% [markdown]
# ### 19. Plot a pie chart with percentage labels.

# %% [markdown]
# ### 20. Explode a slice of the pie chart.

# %% [markdown]
# ### 21. Create a histogram of a random dataset.

# %% [markdown]
# ### 22. Customize number of bins in a histogram.

# %% [markdown]
# ### 23. Create a scatter plot with random values.

# %% [markdown]
# ### 24. Use color and size variations in a scatter plot.

# %% [markdown]
# ### 25. Plot a box plot for numerical data.

# %% [markdown]
# ### 26. Plot a violin plot using seaborn + matplotlib.

# %% [markdown]
# ### 27. Create a stacked bar chart.

# %% [markdown]
# ### 28. Plot an area chart using fill_between().

# %% [markdown]
# ### 29. Create a bubble chart.

# %% [markdown]
# ### 30. Draw a hexbin plot.

# %% [markdown]
# ### 31. Create two subplots side by side.

# %% [markdown]
# ### 32. Create a 2x2 grid of plots using plt.subplot().

# %% [markdown]
# ### 33. Use plt.subplots() with fig, ax.

# %% [markdown]
# ### 34. Share x-axis across subplots.

# %% [markdown]
# ### 35. Share y-axis across subplots.

# %% [markdown]
# ### 36. Adjust spacing between subplots with tight_layout().

# %% [markdown]
# ### 37. Customize figure size using figsize.

# %% [markdown]
# ### 38. Create complex nested subplots using gridspec.

# %% [markdown]
# ### 39. Add a super title for all subplots.

# %% [markdown]
# ### 40. Plot different chart types in one figure (line, bar, pie).

# %% [markdown]
# ### 41. Add axes manually using fig.add_axes().

# %% [markdown]
# ### 42. Use plt.subplot2grid() for advanced layout.

# %% [markdown]
# ### 43. Turn off one of the axes in subplots.

# %% [markdown]
# ### 44. Draw empty subplots and annotate them.

# %% [markdown]
# ### 45. Plot histograms in columns using shared axes.

# %% [markdown]
# ### 46. Change plot style using plt.style.use().

# %% [markdown]
# ### 47. Create a custom style with rcParams.

# %% [markdown]
# ### 48. Change tick parameters (direction, length, width).

# %% [markdown]
# ### 49. Customize font size and family.

# %% [markdown]
# ### 50. Set a dark background for all plots.

# %% [markdown]
# ### 51. Add annotation to a plot using plt.annotate().

# %% [markdown]
# ### 52. Customize legend font size and edge color.

# %% [markdown]
# ### 53. Use different colormaps in scatter plots.

# %% [markdown]
# ### 54. Add arrows and shapes to a plot.

# %% [markdown]
# ### 55. Change axes spines and remove top/right axes.

# %% [markdown]
# ### 56. Add a watermark text to the figure.

# %% [markdown]
# ### 57. Display grid lines only on x-axis.

# %% [markdown]
# ### 58. Change the orientation of ticks.

# %% [markdown]
# ### 59. Format y-axis as percentages.

# %% [markdown]
# ### 60. Use FuncFormatter for custom tick labels.

# %% [markdown]
# ### 61. Plot a 3D surface plot using mpl_toolkits.

# %% [markdown]
# ### 62. Plot a 3D scatter plot with color mapping.

# %% [markdown]
# ### 63. Create a heatmap using imshow().

# %% [markdown]
# ### 64. Create a contour plot of a 2D function.

# %% [markdown]
# ### 65. Plot a dendrogram using hierarchical clustering.

# %% [markdown]
# ### 66. Use brokenaxes for discontinuous axes.

# %% [markdown]
# ### 67. Plot live-updating data using FuncAnimation.

# %% [markdown]
# ### 68. Add multiple y-axes using twinx().

# %% [markdown]
# ### 69. Add inset plots inside the main plot.

# %% [markdown]
# ### 70. Use log scale on y-axis.

# %% [markdown]
# ### 71. Create an interactive plot using %matplotlib notebook.

# %% [markdown]
# ### 72. Create a step plot.

# %% [markdown]
# ### 73. Draw a calendar heatmap.

# %% [markdown]
# ### 74. Visualize a confusion matrix using matplotlib.

# %% [markdown]
# ### 75. Plot a time series line chart with date labels.

# %% [markdown]
# ### 76. Plot a CSV file data using pandas + matplotlib.

# %% [markdown]
# ### 77. Visualize correlation matrix from a DataFrame.

# %% [markdown]
# ### 78. Create a stock price chart with moving averages.

# %% [markdown]
# ### 79. Plot grouped bar charts from a pivot table.

# %% [markdown]
# ### 80. Read an Excel file and plot line charts for different sheets.

# %% [markdown]
# ### 81. Visualize missing data counts in a DataFrame.

# %% [markdown]
# ### 82. Combine seaborn and matplotlib for aesthetic plots.

# %% [markdown]
# ### 83. Visualize a Word Frequency Count as a bar chart.

# %% [markdown]
# ### 84. Create a dashboard-like plot with multiple charts.

# %% [markdown]
# ### 85. Annotate top 3 points in a scatter plot using values from DataFrame.

# %% [markdown]
# ### 86. Save a figure with high resolution.

# %% [markdown]
# ### 87. Save a plot without white padding.

# %% [markdown]
# ### 88. Export a plot as SVG.

# %% [markdown]
# ### 89. Add interactive tooltips using mplcursors.

# %% [markdown]
# ### 90. Integrate Matplotlib plots into a Tkinter GUI.

# %% [markdown]
# ### 91. Add a color bar to a scatter or heatmap.

# %% [markdown]
# ### 92. Create a dual axis plot for revenue and profit.

# %% [markdown]
# ### 93. Save multiple figures to a single PDF using PdfPages.

# %% [markdown]
# ### 94. Create a gif from animated plots.

# %% [markdown]
# ### 95. Use rcParams globally for custom plot themes.

# %% [markdown]
# ### 96. Create plots using the object-oriented API only.

# %% [markdown]
# ### 97. Embed a plot inside a Jupyter notebook cell.

# %% [markdown]
# ### 98. Display multiple figures in sequence programmatically.

# %% [markdown]
# ### 99. Update a plot in real-time using a loop.

# %% [markdown]
# ### 100. Benchmark rendering time of a large number of plots.
